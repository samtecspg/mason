# %%
from mason.util.notebook_environment import NotebookEnvironment

# %%
env = NotebookEnvironment("../.env")
# Out:
# <style>.container { width:100% !important; }</style>
# Current Mason config not set.  Run "mason config -s" to set current config.
# +-----------------+
# | Configurations  |
# +-----------------+
# Config ID    Engine     Client    Configuration
# -----------  ---------  --------  -----------------------------------------------------------------------------------------------------------
# .  1         metastore  glue      {'aws_region': 'us-east-1', 'aws_role_arn': 'REDACTED', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
#              scheduler  glue      {'aws_region': 'us-east-1', 'aws_role_arn': 'REDACTED', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
#              storage    s3        {'aws_region': 'us-east-1', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
#              execution  athena    {'aws_region': 'us-east-1', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
# .  2         metastore  s3        {'aws_region': 'us-east-1', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
#              execution  spark     {'runner': {'spark_version': '2.4.5', 'type': 'kubernetes-operator'}}
# .  3         metastore  athena    {'aws_region': 'us-east-1', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
#              scheduler  local     {}
#              storage    s3        {'aws_region': 'us-east-1', 'access_key': 'REDACTED', 'secret_key': 'REDACTED'}
#
# * = Current Configuration
# +------------------------------------------------------------------------------+
# | Available Operator Methods: /Users/kyle/dev/mason/mason/examples/operators/  |
# +------------------------------------------------------------------------------+
#
# namespace    command    description                         parameters
# -----------  ---------  ----------------------------------  ---------------------------------------------------------------------------------------------------------------
# schedule     delete     Delete schedule                     {'required': ['schedule_name'], 'optional': []}
# table        delete     Delete metastore tables             {'required': ['table_name', 'database_name'], 'optional': []}
# table        merge      Merge metastore tables              {'required': ['output_path', 'input_path'], 'optional': ['extract_paths', 'repartition_keys', 'parse_headers']}
# table        refresh    Refresh metastore tables            {'required': ['database_name', 'table_name'], 'optional': []}
# table        get        Get metastore table contents        {'required': ['database_name', 'table_name'], 'optional': []}
# table        list       Get metastore tables                {'required': ['database_name'], 'optional': []}
# table        infer      Infers schema for metastore tables  {'required': ['database_name', 'storage_path'], 'optional': ['table_name']}
# table        query      Query metastore tables              {'required': ['query_string', 'database_name'], 'optional': []}
# job          get        Get Execution Job Status            {'required': ['job_id'], 'optional': []}
#
# +------------------------------------------------------------------------------+
# | Available Workflow Methods: /Users/kyle/dev/mason/mason/examples/workflows/  |
# +------------------------------------------------------------------------------+
#
# namespace    command          description
# -----------  ---------------  ---------------------------------------------------------------------------------------------
# table        validated_infer  5 step workflow for inferring table and checking if it worked, then cleaning up if it didn't.
# table        infer            One step workfow for table infer operator

# %%
# !aws s3 ls spg-mason-demo/part_data_merged/

# %%
# !aws s3 ls spg-mason-demo/part_data/

# %%
# !aws s3 ls spg-mason-demo/part_data/manufacturer1/

# %%
# !aws s3 ls spg-mason-demo/part_data/manufacturer2/

# %%
run = env.run("table", "get", parameters="database_name:spg-mason-demo,table_name:part_data", config_id="2")

# %%
response = run.response
response.formatted()

# %%
invalid_table = job.object
invalid_table

# %%
response.formatted()

# %%
from mason.clients.response import Response
invalid_table.conflicting_table().to_response(Response()).formatted()

# %%
run = env.run("table", "get", parameters="database_name:spg-mason-demo,table_name:part_data_merged", config_id="2")

# %%
response = run.response
response.formatted()

# %%
table = run.object
table

# %%
table.as_df()

# %%
table.schema.columns

# %%
table.schema.columns[0].to_dict()

# %%
run = env.run("table", "infer", parameters="database_name:crawler_poc,storage_path:spg-mason-demo/part_data", config_id="3")

# %%
run.response.formatted()

# %%
run = env.run("table", "infer", parameters="database_name:crawler_poc,storage_path:spg-mason-demo/part_data_merged", config_id="3")

# %%
run.response.formatted()

# %%
run.object

# %%
run.object.message

# %%
parameters = {}
response = env.run_workflow("table", "validated_infer", parameters, "3")

# %%
parameters = {
    "step_1": {"config_id": "3", "parameters": {}},
    "step_2": {"config_id": "3", "parameters": {}},
    "step_3": {"config_id": "3", "parameters": {}},
    "step_4": {"config_id": "3", "parameters": {}},
    "step_5": {"config_id": "3", "parameters": {}}
}
response = env.run_workflow("table", "validated_infer", parameters, "3")
response.formatted()

# %%
parameters = {
    "step_1": {"config_id": "3", "parameters": {"database_name": "crawler_poc", "storage_path": "spg-mason-demo/part_data/"}},
    "step_2": {"config_id": "3", "parameters": {"job_id": "any"}},
    "step_3": {"config_id": "3", "parameters": {}},
    "step_4": {"config_id": "3", "parameters": {}},
    "step_5": {"config_id": "3", "parameters": {}}
}
response = env.run_workflow("table", "validated_infer", parameters, "3")
response.formatted()

# %%
parameters = {
    "step_1": {"config_id": "3", "parameters": {"database_name": "crawler_poc", "storage_path": "spg-mason-demo/part_data/", "table_name": "test_part_data"}},
    "step_2": {"config_id": "1", "parameters": {"job_id": "any"}},
    "step_3": {"config_id": "1", "parameters": {"query_string": "SELECT * from test_part_data", "database_name":"crawler_poc"}},
    "step_4": {"config_id": "1", "parameters": {"job_id": "any"}},
    "step_5": {"config_id": "1", "parameters": {"table_name": "test_part_data", "database_name": "crawler_poc"}}
}
response = env.run_workflow("table", "validated_infer", parameters, "3")
response.formatted()
# Out:
# Set log level to trace
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# 2020-06-19 15:53:17.408545: Performing Dry Run for Workflow.  To Deploy workflow use --deploy -d flag.  To run now use the --run -r flag
# 2020-06-19 15:53:17.408680
# 2020-06-19 15:53:17.408700: Valid Workflow DAG Definition:
# 2020-06-19 15:53:17.408716: --------------------------------------------------------------------------------
# 2020-06-19 15:53:17.411113: * step_1
# * step_2
# * step_3
# * step_4
# * step_5
#
# 2020-06-19 15:53:17.411263
# {'Errors': [],
#  'Info': ['2020-06-19 15:53:17.408545: Performing Dry Run for Workflow.  To Deploy workflow use --deploy -d flag.  To run now use the --run -r flag',
#   '2020-06-19 15:53:17.408680',
#   '2020-06-19 15:53:17.408700: Valid Workflow DAG Definition:',
#   '2020-06-19 15:53:17.408716: --------------------------------------------------------------------------------',
#   '2020-06-19 15:53:17.411113: * step_1\n* step_2\n* step_3\n* step_4\n* step_5\n',
#   '2020-06-19 15:53:17.411263'],
#  'Warnings': [],
#  '_client_responses': []}

# %%
response = env.run_workflow("table", "validated_infer", parameters, "3", deploy=True)
# Out:
# Set log level to trace
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# 2020-06-19 15:53:26.533736: Registering workflow dag table_validated_infer_0a8a5f4a-2c68-4968-b0b1-2cc7a6daf1bd with local.
# 2020-06-19 15:53:26.533834: Registering DAG in local memory
# 2020-06-19 15:53:26.533857: Registered schedule table_validated_infer_0a8a5f4a-2c68-4968-b0b1-2cc7a6daf1bd

# %%
response = env.run_workflow("table", "validated_infer", parameters, config_id="3", deploy=True, run_now=True)
# Out:
# Set log level to trace
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# 2020-06-19 15:53:30.314604: Registering workflow dag table_validated_infer_e2038477-c072-49bd-b1d2-46dd140c0674 with local.
# 2020-06-19 15:53:30.314762: Registering DAG in local memory
# 2020-06-19 15:53:30.314827: Registered schedule table_validated_infer_e2038477-c072-49bd-b1d2-46dd140c0674
# 2020-06-19 15:53:30.314845: Triggering schedule: table_validated_infer_e2038477-c072-49bd-b1d2-46dd140c0674
# 2020-06-19 15:53:30.315913: Running dag
# * step_1
# * step_2
# * step_3
# * step_4
# * step_5
#
# Running steps: step_1
# 2020-06-19 15:53:30.316110: Running step step_1
# Fetching keys at s3://spg-mason-demo/part_data/
# 2020-06-19 15:53:31.131461: Conflicting Schemas
# 2020-06-19 15:53:31.131621: Job errored: Invalid Tables: Conflicting Schemas
# 2020-06-19 15:53:31.137921: Workflow failed

# %%
response.formatted()
# Out:
# {'Errors': ['2020-06-19 15:53:31.131461: Conflicting Schemas',
#   '2020-06-19 15:53:31.131621: Job errored: Invalid Tables: Conflicting Schemas',
#   '2020-06-19 15:53:31.137921: Workflow failed'],
#  'Info': ['2020-06-19 15:53:30.314604: Registering workflow dag table_validated_infer_e2038477-c072-49bd-b1d2-46dd140c0674 with local.',
#   '2020-06-19 15:53:30.314762: Registering DAG in local memory',
#   '2020-06-19 15:53:30.314827: Registered schedule table_validated_infer_e2038477-c072-49bd-b1d2-46dd140c0674',
#   '2020-06-19 15:53:30.314845: Triggering schedule: table_validated_infer_e2038477-c072-49bd-b1d2-46dd140c0674',
#   '2020-06-19 15:53:30.315913: Running dag \n* step_1\n* step_2\n* step_3\n* step_4\n* step_5\n',
#   '2020-06-19 15:53:30.316110: Running step step_1'],
#  'Warnings': [],
#  'Data': [{'SchemaConflicts': {'CountDistinctSchemas': 2,
#     'DistinctSchemas': [{'SchemaType': 'parquet',
#       'Columns': [{'Name': 'widget',
#         'Type': 'BYTE_ARRAY',
#         'ConvertedType': 'UTF8',
#         'RepititionType': 'OPTIONAL'},
#        {'Name': 'price',
#         'Type': 'FLOAT',
#         'ConvertedType': 'REQUIRED',
#         'RepititionType': None},
#        {'Name': 'manufacturer',
#         'Type': 'BYTE_ARRAY',
#         'ConvertedType': 'UTF8',
#         'RepititionType': 'OPTIONAL'},
#        {'Name': 'in_stock',
#         'Type': 'BOOLEAN',
#         'ConvertedType': 'REQUIRED',
#         'RepititionType': None}]},
#      {'SchemaType': 'parquet',
#       'Columns': [{'Name': 'widget',
#         'Type': 'BYTE_ARRAY',
#         'ConvertedType': 'UTF8',
#         'RepititionType': 'OPTIONAL'},
#        {'Name': 'price',
#         'Type': 'DOUBLE',
#         'ConvertedType': 'REQUIRED',
#         'RepititionType': None},
#        {'Name': 'manufacturer',
#         'Type': 'BYTE_ARRAY',
#         'ConvertedType': 'UTF8',
#         'RepititionType': 'OPTIONAL'},
#        {'Name': 'in_stock',
#         'Type': 'BOOLEAN',
#         'ConvertedType': 'REQUIRED',
#         'RepititionType': None}]}],
#     'NonOverlappingColumns': [{'name': 'price', 'type': 'FLOAT'},
#      {'name': 'price', 'type': 'DOUBLE'}]}}],
#  '_client_responses': []}

# %%
parameters = {
    "step_1": {"config_id": "3", "parameters": {"database_name": "crawler_poc", "storage_path": "spg-mason-demo/part_data_merged/", "table_name": "part_data_merged"}},
    "step_2": {"config_id": "1", "parameters": {"job_id": "any"}},
    "step_3": {"config_id": "1", "parameters": {"query_string": "SELECT * from part_data_merged", "database_name":"crawler_poc"}},
    "step_4": {"config_id": "1", "parameters": {"job_id": "any"}},
    "step_5": {"config_id": "1", "parameters": {"table_name": "part_data_merged", "database_name": "crawler_poc"}}
}
response = env.run_workflow("table", "validated_infer", parameters, "3", deploy=True, run_now=True)
# Out:
# Set log level to trace
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# Reading configurations at /Users/kyle/dev/mason/mason/examples/configs/
# 2020-06-19 15:54:20.984776: Registering workflow dag table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4 with local.
# 2020-06-19 15:54:20.984928: Registering DAG in local memory
# 2020-06-19 15:54:20.985178: Registered schedule table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4
# 2020-06-19 15:54:20.985214: Triggering schedule: table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4
# 2020-06-19 15:54:20.986323: Running dag
# * step_1
# * step_2
# * step_3
# * step_4
# * step_5
#
# Running steps: step_1
# 2020-06-19 15:54:20.986523: Running step step_1
# Fetching keys at s3://spg-mason-demo/part_data_merged/
# 2020-06-19 15:54:21.493042: Table inferred: part_data_merged
# 2020-06-19 15:54:22.370745: Running Athena query.  query_id: 0d2fb38b-5b7a-40b9-816b-52eccbe41039
# 2020-06-19 15:54:22.370846: Running job id=0d2fb38b-5b7a-40b9-816b-52eccbe41039
# Running steps: step_2
# 2020-06-19 15:54:22.371067: Running step step_2
# 2020-06-19 15:54:22.606240: Job Status: RUNNING
# 2020-06-19 15:54:22.812425: Job failed (retryable): Query has not yet finished. Current state: RUNNING
# 2020-06-19 15:54:22.812930: Retrying step step_2. Attempt 1
# Running steps: step_2
# 2020-06-19 15:54:32.815654: Running step step_2
# 2020-06-19 15:54:33.060703: Job Status: SUCCEEDED
# Running steps: step_3
# 2020-06-19 15:54:33.351041: Running step step_3
# 2020-06-19 15:54:33.692453: Running Query "SELECT * from part_data_merged"
# 2020-06-19 15:54:34.023095: Running Athena query.  query_id: b5b045ad-029b-4cc3-920c-10d48a25fe0e
# 2020-06-19 15:54:34.023196: Running job id=b5b045ad-029b-4cc3-920c-10d48a25fe0e
# Running steps: step_4
# 2020-06-19 15:54:34.023401: Running step step_4
# 2020-06-19 15:54:34.210876: Job Status: QUEUED
# 2020-06-19 15:54:34.427048: Job failed (retryable): Query has not yet finished. Current state: RUNNING
# 2020-06-19 15:54:34.427329: Retrying step step_4. Attempt 1
# Running steps: step_4
# 2020-06-19 15:54:44.428057: Running step step_4
# 2020-06-19 15:54:44.614793: Job Status: SUCCEEDED
# 2020-06-19 15:54:44.931351: Query Succesful, not cleaning up table
# 2020-06-19 15:54:44.931454: Workflow Successful
# {'Errors': [],
#  'Info': ['2020-06-19 15:54:20.984776: Registering workflow dag table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4 with local.',
#   '2020-06-19 15:54:20.984928: Registering DAG in local memory',
#   '2020-06-19 15:54:20.985178: Registered schedule table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4',
#   '2020-06-19 15:54:20.985214: Triggering schedule: table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4',
#   '2020-06-19 15:54:20.986323: Running dag \n* step_1\n* step_2\n* step_3\n* step_4\n* step_5\n',
#   '2020-06-19 15:54:20.986523: Running step step_1',
#   '2020-06-19 15:54:21.493042: Table inferred: part_data_merged',
#   '2020-06-19 15:54:22.370745: Running Athena query.  query_id: 0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#   '2020-06-19 15:54:22.370846: Running job id=0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#   '2020-06-19 15:54:22.371067: Running step step_2',
#   '2020-06-19 15:54:22.606240: Job Status: RUNNING',
#   '2020-06-19 15:54:22.812930: Retrying step step_2. Attempt 1',
#   '2020-06-19 15:54:32.815654: Running step step_2',
#   '2020-06-19 15:54:33.060703: Job Status: SUCCEEDED',
#   '2020-06-19 15:54:33.692453: Running Query "SELECT * from part_data_merged"',
#   '2020-06-19 15:54:34.023095: Running Athena query.  query_id: b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#   '2020-06-19 15:54:34.023196: Running job id=b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#   '2020-06-19 15:54:34.023401: Running step step_4',
#   '2020-06-19 15:54:34.210876: Job Status: QUEUED',
#   '2020-06-19 15:54:34.427329: Retrying step step_4. Attempt 1',
#   '2020-06-19 15:54:44.428057: Running step step_4',
#   '2020-06-19 15:54:44.614793: Job Status: SUCCEEDED',
#   '2020-06-19 15:54:44.931351: Query Succesful, not cleaning up table',
#   '2020-06-19 15:54:44.931454: Workflow Successful'],
#  'Warnings': ['2020-06-19 15:54:22.812425: Job failed (retryable): Query has not yet finished. Current state: RUNNING',
#   '2020-06-19 15:54:34.427048: Job failed (retryable): Query has not yet finished. Current state: RUNNING'],
#  'Data': [{'Rows': [{'Data': [{'VarCharValue': 'widget'},
#       {'VarCharValue': 'price'},
#       {'VarCharValue': 'manufacturer'},
#       {'VarCharValue': 'in_stock'}]},
#     {'Data': [{'VarCharValue': 'tractor'},
#       {'VarCharValue': '10000.0'},
#       {'VarCharValue': 'John Deer'},
#       {'VarCharValue': 'true'}]},
#     {'Data': [{'VarCharValue': 'forklift'},
#       {'VarCharValue': '4000.0'},
#       {'VarCharValue': 'Bobcat'},
#       {'VarCharValue': 'true'}]},
#     {'Data': [{'VarCharValue': 'crane'},
#       {'VarCharValue': '5000.0'},
#       {'VarCharValue': 'Case'},
#       {'VarCharValue': 'false'}]},
#     {'Data': [{'VarCharValue': 'wrench'}, {'VarCharValue': '20.0'}, {}, {}]},
#     {'Data': [{'VarCharValue': 'casing'}, {'VarCharValue': '30.0'}, {}, {}]},
#     {'Data': [{'VarCharValue': 'bolt'}, {'VarCharValue': '25.0'}, {}, {}]}],
#    'ResultSetMetadata': {'ColumnInfo': [{'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'widget',
#       'Label': 'widget',
#       'Type': 'varchar',
#       'Precision': 2147483647,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': True},
#      {'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'price',
#       'Label': 'price',
#       'Type': 'double',
#       'Precision': 17,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': False},
#      {'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'manufacturer',
#       'Label': 'manufacturer',
#       'Type': 'varchar',
#       'Precision': 2147483647,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': True},
#      {'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'in_stock',
#       'Label': 'in_stock',
#       'Type': 'boolean',
#       'Precision': 0,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': False}]}}],
#  '_client_responses': [{'TableList': [{'Name': 'complex_json_2_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field6:string>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json_2.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '272',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '272',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '272',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '272',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'complex_json_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field5:struct<some_other_stuff:string>>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '302',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '302',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '302',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '302',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'json_simple_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'field', 'Type': 'string'},
#        {'Name': 'field2', 'Type': 'string'},
#        {'Name': 'field3', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/part_data_json/json_simple.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'field,field2,field3'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '58',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '58',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '58',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '58',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/merged/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '82',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '3',
#        'recordCount': '6',
#        'sizeKey': '2115',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '82',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '3',
#       'recordCount': '6',
#       'sizeKey': '2115',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1591706397'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '189',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '8',
#        'recordCount': '6',
#        'sizeKey': '5309',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '189',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '8',
#       'recordCount': '6',
#       'sizeKey': '5309',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'col0', 'Type': 'string'},
#        {'Name': 'col1', 'Type': 'double'},
#        {'Name': 'col2', 'Type': 'string'},
#        {'Name': 'col3', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_csv/',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe',
#        'Parameters': {'field.delim': ','}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'areColumnsQuoted': 'false',
#        'averageRecordSize': '18',
#        'classification': 'csv',
#        'columnsOrdered': 'true',
#        'compressionType': 'none',
#        'delimiter': ',',
#        'objectCount': '4',
#        'recordCount': '6',
#        'sizeKey': '117',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'areColumnsQuoted': 'false',
#       'averageRecordSize': '18',
#       'classification': 'csv',
#       'columnsOrdered': 'true',
#       'compressionType': 'none',
#       'delimiter': ',',
#       'objectCount': '4',
#       'recordCount': '6',
#       'sizeKey': '117',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_merged',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592595887'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'problem',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'index', 'Type': 'bigint'},
#        {'Name': 'transactiontime', 'Type': 'string'},
#        {'Name': 'user_master_id', 'Type': 'bigint'},
#        {'Name': 'user_name', 'Type': 'string'},
#        {'Name': 'first_name', 'Type': 'string'},
#        {'Name': 'last_name', 'Type': 'string'},
#        {'Name': 'full_name', 'Type': 'string'},
#        {'Name': 'facility_id', 'Type': 'bigint'},
#        {'Name': 'title_id', 'Type': 'bigint'},
#        {'Name': 'department_id', 'Type': 'bigint'},
#        {'Name': 'active', 'Type': 'string'},
#        {'Name': 'associate_number', 'Type': 'double'},
#        {'Name': 'entered_by_id', 'Type': 'bigint'},
#        {'Name': 'date_entered', 'Type': 'timestamp'},
#        {'Name': 'user_id', 'Type': 'bigint'},
#        {'Name': 'date_write', 'Type': 'timestamp'},
#        {'Name': 'date_hire', 'Type': 'timestamp'},
#        {'Name': 'birth_month', 'Type': 'double'},
#        {'Name': 'birth_day', 'Type': 'double'},
#        {'Name': 'date_terminated', 'Type': 'timestamp'},
#        {'Name': 'plant_id', 'Type': 'double'},
#        {'Name': 'itar_approved', 'Type': 'double'},
#        {'Name': 'issharedaccount', 'Type': 'double'},
#        {'Name': 'rowguid', 'Type': 'string'},
#        {'Name': 'dateofbirth', 'Type': 'timestamp'},
#        {'Name': 'exporttoexternal', 'Type': 'double'},
#        {'Name': 'dateupdatetocsod', 'Type': 'timestamp'},
#        {'Name': 'productivitycenterid', 'Type': 'double'},
#        {'Name': 'ar_h_change_seq', 'Type': 'string'},
#        {'Name': 'ar_h_stream_position', 'Type': 'string'},
#        {'Name': 'op', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/problem/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '277',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '2',
#        'recordCount': '23423',
#        'sizeKey': '1310155',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '277',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '2',
#       'recordCount': '23423',
#       'sizeKey': '1310155',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'test_table',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592421546'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False}],
#    'ResponseMetadata': {'RequestId': 'db0aa17b-121c-4c0d-a13b-e8aad9212d95',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'date': 'Fri, 19 Jun 2020 19:54:21 GMT',
#      'content-type': 'application/x-amz-json-1.1',
#      'content-length': '15324',
#      'connection': 'keep-alive',
#      'x-amzn-requestid': 'db0aa17b-121c-4c0d-a13b-e8aad9212d95'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:21.946172'},
#   {'QueryExecutionId': '0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#    'ResponseMetadata': {'RequestId': 'ac92eda0-065d-450e-9da6-850dff9e42f8',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:21 GMT',
#      'x-amzn-requestid': 'ac92eda0-065d-450e-9da6-850dff9e42f8',
#      'content-length': '59',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:22.370675'},
#   {'QueryExecution': {'QueryExecutionId': '0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#     'Query': "CREATE EXTERNAL TABLE IF NOT EXISTS `crawler_poc`.`part_data_merged` (\n`widget` STRING,\n`price` DOUBLE,\n`manufacturer` STRING,\n`in_stock` BOOLEAN\n)\nSTORED AS PARQUET\nLOCATION 's3://spg-mason-demo/part_data_merged/'",
#     'StatementType': 'DDL',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/0d2fb38b-5b7a-40b9-816b-52eccbe41039.txt'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'RUNNING',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 22, 304000, tzinfo=tzlocal())},
#     'Statistics': {'TotalExecutionTimeInMillis': 264,
#      'QueryQueueTimeInMillis': 55},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': 'ebba07f6-d29f-418d-9aa1-dc0631bb61cb',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:21 GMT',
#      'x-amzn-requestid': 'ebba07f6-d29f-418d-9aa1-dc0631bb61cb',
#      'content-length': '1316',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:22.606214'},
#   {'Error': {'Message': 'Query has not yet finished. Current state: RUNNING',
#     'Code': 'InvalidRequestException'},
#    'ResponseMetadata': {'RequestId': '78aa1f97-8f0d-42b8-8b62-dfaea163bd3f',
#     'HTTPStatusCode': 400,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:22 GMT',
#      'x-amzn-requestid': '78aa1f97-8f0d-42b8-8b62-dfaea163bd3f',
#      'content-length': '193',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:22.812393'},
#   {'QueryExecution': {'QueryExecutionId': '0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#     'Query': "CREATE EXTERNAL TABLE IF NOT EXISTS `crawler_poc`.`part_data_merged` (\n`widget` STRING,\n`price` DOUBLE,\n`manufacturer` STRING,\n`in_stock` BOOLEAN\n)\nSTORED AS PARQUET\nLOCATION 's3://spg-mason-demo/part_data_merged/'",
#     'StatementType': 'DDL',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/0d2fb38b-5b7a-40b9-816b-52eccbe41039.txt'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'SUCCEEDED',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 22, 304000, tzinfo=tzlocal()),
#      'CompletionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 22, 754000, tzinfo=tzlocal())},
#     'Statistics': {'EngineExecutionTimeInMillis': 365,
#      'DataScannedInBytes': 0,
#      'TotalExecutionTimeInMillis': 450,
#      'QueryQueueTimeInMillis': 55,
#      'ServiceProcessingTimeInMillis': 30},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': '2f273530-8cf6-4b8c-8ee2-9ad989278796',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:32 GMT',
#      'x-amzn-requestid': '2f273530-8cf6-4b8c-8ee2-9ad989278796',
#      'content-length': '1605',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:33.060688'},
#   {'ResultSet': {'Rows': [], 'ResultSetMetadata': {'ColumnInfo': []}},
#    'ResponseMetadata': {'RequestId': 'a1c398dd-090d-4921-8a2e-fcd275ff7ed1',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:32 GMT',
#      'x-amzn-requestid': 'a1c398dd-090d-4921-8a2e-fcd275ff7ed1',
#      'content-length': '108',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:33.350742'},
#   {'TableList': [{'Name': 'complex_json_2_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field6:string>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json_2.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '272',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '272',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '272',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '272',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'complex_json_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field5:struct<some_other_stuff:string>>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '302',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '302',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '302',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '302',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'json_simple_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'field', 'Type': 'string'},
#        {'Name': 'field2', 'Type': 'string'},
#        {'Name': 'field3', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/part_data_json/json_simple.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'field,field2,field3'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '58',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '58',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '58',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '58',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/merged/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '82',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '3',
#        'recordCount': '6',
#        'sizeKey': '2115',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '82',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '3',
#       'recordCount': '6',
#       'sizeKey': '2115',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1591706397'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '189',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '8',
#        'recordCount': '6',
#        'sizeKey': '5309',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '189',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '8',
#       'recordCount': '6',
#       'sizeKey': '5309',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'col0', 'Type': 'string'},
#        {'Name': 'col1', 'Type': 'double'},
#        {'Name': 'col2', 'Type': 'string'},
#        {'Name': 'col3', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_csv/',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe',
#        'Parameters': {'field.delim': ','}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'areColumnsQuoted': 'false',
#        'averageRecordSize': '18',
#        'classification': 'csv',
#        'columnsOrdered': 'true',
#        'compressionType': 'none',
#        'delimiter': ',',
#        'objectCount': '4',
#        'recordCount': '6',
#        'sizeKey': '117',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'areColumnsQuoted': 'false',
#       'averageRecordSize': '18',
#       'classification': 'csv',
#       'columnsOrdered': 'true',
#       'compressionType': 'none',
#       'delimiter': ',',
#       'objectCount': '4',
#       'recordCount': '6',
#       'sizeKey': '117',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_merged',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592595887'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'problem',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'index', 'Type': 'bigint'},
#        {'Name': 'transactiontime', 'Type': 'string'},
#        {'Name': 'user_master_id', 'Type': 'bigint'},
#        {'Name': 'user_name', 'Type': 'string'},
#        {'Name': 'first_name', 'Type': 'string'},
#        {'Name': 'last_name', 'Type': 'string'},
#        {'Name': 'full_name', 'Type': 'string'},
#        {'Name': 'facility_id', 'Type': 'bigint'},
#        {'Name': 'title_id', 'Type': 'bigint'},
#        {'Name': 'department_id', 'Type': 'bigint'},
#        {'Name': 'active', 'Type': 'string'},
#        {'Name': 'associate_number', 'Type': 'double'},
#        {'Name': 'entered_by_id', 'Type': 'bigint'},
#        {'Name': 'date_entered', 'Type': 'timestamp'},
#        {'Name': 'user_id', 'Type': 'bigint'},
#        {'Name': 'date_write', 'Type': 'timestamp'},
#        {'Name': 'date_hire', 'Type': 'timestamp'},
#        {'Name': 'birth_month', 'Type': 'double'},
#        {'Name': 'birth_day', 'Type': 'double'},
#        {'Name': 'date_terminated', 'Type': 'timestamp'},
#        {'Name': 'plant_id', 'Type': 'double'},
#        {'Name': 'itar_approved', 'Type': 'double'},
#        {'Name': 'issharedaccount', 'Type': 'double'},
#        {'Name': 'rowguid', 'Type': 'string'},
#        {'Name': 'dateofbirth', 'Type': 'timestamp'},
#        {'Name': 'exporttoexternal', 'Type': 'double'},
#        {'Name': 'dateupdatetocsod', 'Type': 'timestamp'},
#        {'Name': 'productivitycenterid', 'Type': 'double'},
#        {'Name': 'ar_h_change_seq', 'Type': 'string'},
#        {'Name': 'ar_h_stream_position', 'Type': 'string'},
#        {'Name': 'op', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/problem/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '277',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '2',
#        'recordCount': '23423',
#        'sizeKey': '1310155',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '277',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '2',
#       'recordCount': '23423',
#       'sizeKey': '1310155',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'test_table',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592421546'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False}],
#    'ResponseMetadata': {'RequestId': '4456b5e7-13b3-4f5e-acfd-606e29209d8d',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'content-type': 'application/x-amz-json-1.1',
#      'content-length': '15324',
#      'connection': 'keep-alive',
#      'x-amzn-requestid': '4456b5e7-13b3-4f5e-acfd-606e29209d8d'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:33.692323'},
#   {'QueryExecutionId': 'b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#    'ResponseMetadata': {'RequestId': '02f32c7a-c258-4cd6-b88b-48b867d5bf33',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'x-amzn-requestid': '02f32c7a-c258-4cd6-b88b-48b867d5bf33',
#      'content-length': '59',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:34.023024'},
#   {'QueryExecution': {'QueryExecutionId': 'b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#     'Query': 'SELECT * from part_data_merged',
#     'StatementType': 'DML',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/b5b045ad-029b-4cc3-920c-10d48a25fe0e.csv'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'QUEUED',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 33, 952000, tzinfo=tzlocal())},
#     'Statistics': {'TotalExecutionTimeInMillis': 222,
#      'QueryQueueTimeInMillis': 222},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': 'c52ccc82-0bf3-4f4f-958e-4dea84511c6e',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'x-amzn-requestid': 'c52ccc82-0bf3-4f4f-958e-4dea84511c6e',
#      'content-length': '934',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:34.210845'},
#   {'Error': {'Message': 'Query has not yet finished. Current state: RUNNING',
#     'Code': 'InvalidRequestException'},
#    'ResponseMetadata': {'RequestId': '8c685ec7-9917-4f5f-9d3f-d4eefa5a704b',
#     'HTTPStatusCode': 400,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'x-amzn-requestid': '8c685ec7-9917-4f5f-9d3f-d4eefa5a704b',
#      'content-length': '193',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:34.427014'},
#   {'QueryExecution': {'QueryExecutionId': 'b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#     'Query': 'SELECT * from part_data_merged',
#     'StatementType': 'DML',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/b5b045ad-029b-4cc3-920c-10d48a25fe0e.csv'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'SUCCEEDED',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 33, 952000, tzinfo=tzlocal()),
#      'CompletionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 34, 704000, tzinfo=tzlocal())},
#     'Statistics': {'EngineExecutionTimeInMillis': 597,
#      'DataScannedInBytes': 506,
#      'TotalExecutionTimeInMillis': 752,
#      'QueryQueueTimeInMillis': 135,
#      'QueryPlanningTimeInMillis': 254,
#      'ServiceProcessingTimeInMillis': 20},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': 'cb980a0b-48c3-426e-95c3-fa20aa57158f',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:43 GMT',
#      'x-amzn-requestid': 'cb980a0b-48c3-426e-95c3-fa20aa57158f',
#      'content-length': '1262',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:44.614777'},
#   {'UpdateCount': 0,
#    'ResultSet': {'Rows': [{'Data': [{'VarCharValue': 'widget'},
#        {'VarCharValue': 'price'},
#        {'VarCharValue': 'manufacturer'},
#        {'VarCharValue': 'in_stock'}]},
#      {'Data': [{'VarCharValue': 'tractor'},
#        {'VarCharValue': '10000.0'},
#        {'VarCharValue': 'John Deer'},
#        {'VarCharValue': 'true'}]},
#      {'Data': [{'VarCharValue': 'forklift'},
#        {'VarCharValue': '4000.0'},
#        {'VarCharValue': 'Bobcat'},
#        {'VarCharValue': 'true'}]},
#      {'Data': [{'VarCharValue': 'crane'},
#        {'VarCharValue': '5000.0'},
#        {'VarCharValue': 'Case'},
#        {'VarCharValue': 'false'}]},
#      {'Data': [{'VarCharValue': 'wrench'}, {'VarCharValue': '20.0'}, {}, {}]},
#      {'Data': [{'VarCharValue': 'casing'}, {'VarCharValue': '30.0'}, {}, {}]},
#      {'Data': [{'VarCharValue': 'bolt'}, {'VarCharValue': '25.0'}, {}, {}]}],
#     'ResultSetMetadata': {'ColumnInfo': [{'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'widget',
#        'Label': 'widget',
#        'Type': 'varchar',
#        'Precision': 2147483647,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': True},
#       {'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'price',
#        'Label': 'price',
#        'Type': 'double',
#        'Precision': 17,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': False},
#       {'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'manufacturer',
#        'Label': 'manufacturer',
#        'Type': 'varchar',
#        'Precision': 2147483647,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': True},
#       {'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'in_stock',
#        'Label': 'in_stock',
#        'Type': 'boolean',
#        'Precision': 0,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': False}]}},
#    'ResponseMetadata': {'RequestId': '9262539c-bacb-4a90-a79f-0d72e4744a98',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:44 GMT',
#      'x-amzn-requestid': '9262539c-bacb-4a90-a79f-0d72e4744a98',
#      'content-length': '2504',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:44.931223'}]}

# %%
response.formatted()
# Out:
# {'Errors': [],
#  'Info': ['2020-06-19 15:54:20.984776: Registering workflow dag table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4 with local.',
#   '2020-06-19 15:54:20.984928: Registering DAG in local memory',
#   '2020-06-19 15:54:20.985178: Registered schedule table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4',
#   '2020-06-19 15:54:20.985214: Triggering schedule: table_validated_infer_5ee25b45-7a39-47cb-b45e-05d7b2a16ac4',
#   '2020-06-19 15:54:20.986323: Running dag \n* step_1\n* step_2\n* step_3\n* step_4\n* step_5\n',
#   '2020-06-19 15:54:20.986523: Running step step_1',
#   '2020-06-19 15:54:21.493042: Table inferred: part_data_merged',
#   '2020-06-19 15:54:22.370745: Running Athena query.  query_id: 0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#   '2020-06-19 15:54:22.370846: Running job id=0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#   '2020-06-19 15:54:22.371067: Running step step_2',
#   '2020-06-19 15:54:22.606240: Job Status: RUNNING',
#   '2020-06-19 15:54:22.812930: Retrying step step_2. Attempt 1',
#   '2020-06-19 15:54:32.815654: Running step step_2',
#   '2020-06-19 15:54:33.060703: Job Status: SUCCEEDED',
#   '2020-06-19 15:54:33.692453: Running Query "SELECT * from part_data_merged"',
#   '2020-06-19 15:54:34.023095: Running Athena query.  query_id: b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#   '2020-06-19 15:54:34.023196: Running job id=b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#   '2020-06-19 15:54:34.023401: Running step step_4',
#   '2020-06-19 15:54:34.210876: Job Status: QUEUED',
#   '2020-06-19 15:54:34.427329: Retrying step step_4. Attempt 1',
#   '2020-06-19 15:54:44.428057: Running step step_4',
#   '2020-06-19 15:54:44.614793: Job Status: SUCCEEDED',
#   '2020-06-19 15:54:44.931351: Query Succesful, not cleaning up table',
#   '2020-06-19 15:54:44.931454: Workflow Successful'],
#  'Warnings': ['2020-06-19 15:54:22.812425: Job failed (retryable): Query has not yet finished. Current state: RUNNING',
#   '2020-06-19 15:54:34.427048: Job failed (retryable): Query has not yet finished. Current state: RUNNING'],
#  'Data': [{'Rows': [{'Data': [{'VarCharValue': 'widget'},
#       {'VarCharValue': 'price'},
#       {'VarCharValue': 'manufacturer'},
#       {'VarCharValue': 'in_stock'}]},
#     {'Data': [{'VarCharValue': 'tractor'},
#       {'VarCharValue': '10000.0'},
#       {'VarCharValue': 'John Deer'},
#       {'VarCharValue': 'true'}]},
#     {'Data': [{'VarCharValue': 'forklift'},
#       {'VarCharValue': '4000.0'},
#       {'VarCharValue': 'Bobcat'},
#       {'VarCharValue': 'true'}]},
#     {'Data': [{'VarCharValue': 'crane'},
#       {'VarCharValue': '5000.0'},
#       {'VarCharValue': 'Case'},
#       {'VarCharValue': 'false'}]},
#     {'Data': [{'VarCharValue': 'wrench'}, {'VarCharValue': '20.0'}, {}, {}]},
#     {'Data': [{'VarCharValue': 'casing'}, {'VarCharValue': '30.0'}, {}, {}]},
#     {'Data': [{'VarCharValue': 'bolt'}, {'VarCharValue': '25.0'}, {}, {}]}],
#    'ResultSetMetadata': {'ColumnInfo': [{'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'widget',
#       'Label': 'widget',
#       'Type': 'varchar',
#       'Precision': 2147483647,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': True},
#      {'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'price',
#       'Label': 'price',
#       'Type': 'double',
#       'Precision': 17,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': False},
#      {'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'manufacturer',
#       'Label': 'manufacturer',
#       'Type': 'varchar',
#       'Precision': 2147483647,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': True},
#      {'CatalogName': 'hive',
#       'SchemaName': '',
#       'TableName': '',
#       'Name': 'in_stock',
#       'Label': 'in_stock',
#       'Type': 'boolean',
#       'Precision': 0,
#       'Scale': 0,
#       'Nullable': 'UNKNOWN',
#       'CaseSensitive': False}]}}],
#  '_client_responses': [{'TableList': [{'Name': 'complex_json_2_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field6:string>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json_2.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '272',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '272',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '272',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '272',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'complex_json_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field5:struct<some_other_stuff:string>>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '302',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '302',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '302',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '302',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'json_simple_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'field', 'Type': 'string'},
#        {'Name': 'field2', 'Type': 'string'},
#        {'Name': 'field3', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/part_data_json/json_simple.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'field,field2,field3'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '58',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '58',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '58',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '58',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/merged/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '82',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '3',
#        'recordCount': '6',
#        'sizeKey': '2115',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '82',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '3',
#       'recordCount': '6',
#       'sizeKey': '2115',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1591706397'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '189',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '8',
#        'recordCount': '6',
#        'sizeKey': '5309',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '189',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '8',
#       'recordCount': '6',
#       'sizeKey': '5309',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'col0', 'Type': 'string'},
#        {'Name': 'col1', 'Type': 'double'},
#        {'Name': 'col2', 'Type': 'string'},
#        {'Name': 'col3', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_csv/',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe',
#        'Parameters': {'field.delim': ','}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'areColumnsQuoted': 'false',
#        'averageRecordSize': '18',
#        'classification': 'csv',
#        'columnsOrdered': 'true',
#        'compressionType': 'none',
#        'delimiter': ',',
#        'objectCount': '4',
#        'recordCount': '6',
#        'sizeKey': '117',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'areColumnsQuoted': 'false',
#       'averageRecordSize': '18',
#       'classification': 'csv',
#       'columnsOrdered': 'true',
#       'compressionType': 'none',
#       'delimiter': ',',
#       'objectCount': '4',
#       'recordCount': '6',
#       'sizeKey': '117',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_merged',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592595887'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'problem',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'index', 'Type': 'bigint'},
#        {'Name': 'transactiontime', 'Type': 'string'},
#        {'Name': 'user_master_id', 'Type': 'bigint'},
#        {'Name': 'user_name', 'Type': 'string'},
#        {'Name': 'first_name', 'Type': 'string'},
#        {'Name': 'last_name', 'Type': 'string'},
#        {'Name': 'full_name', 'Type': 'string'},
#        {'Name': 'facility_id', 'Type': 'bigint'},
#        {'Name': 'title_id', 'Type': 'bigint'},
#        {'Name': 'department_id', 'Type': 'bigint'},
#        {'Name': 'active', 'Type': 'string'},
#        {'Name': 'associate_number', 'Type': 'double'},
#        {'Name': 'entered_by_id', 'Type': 'bigint'},
#        {'Name': 'date_entered', 'Type': 'timestamp'},
#        {'Name': 'user_id', 'Type': 'bigint'},
#        {'Name': 'date_write', 'Type': 'timestamp'},
#        {'Name': 'date_hire', 'Type': 'timestamp'},
#        {'Name': 'birth_month', 'Type': 'double'},
#        {'Name': 'birth_day', 'Type': 'double'},
#        {'Name': 'date_terminated', 'Type': 'timestamp'},
#        {'Name': 'plant_id', 'Type': 'double'},
#        {'Name': 'itar_approved', 'Type': 'double'},
#        {'Name': 'issharedaccount', 'Type': 'double'},
#        {'Name': 'rowguid', 'Type': 'string'},
#        {'Name': 'dateofbirth', 'Type': 'timestamp'},
#        {'Name': 'exporttoexternal', 'Type': 'double'},
#        {'Name': 'dateupdatetocsod', 'Type': 'timestamp'},
#        {'Name': 'productivitycenterid', 'Type': 'double'},
#        {'Name': 'ar_h_change_seq', 'Type': 'string'},
#        {'Name': 'ar_h_stream_position', 'Type': 'string'},
#        {'Name': 'op', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/problem/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '277',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '2',
#        'recordCount': '23423',
#        'sizeKey': '1310155',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '277',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '2',
#       'recordCount': '23423',
#       'sizeKey': '1310155',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'test_table',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592421546'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False}],
#    'ResponseMetadata': {'RequestId': 'db0aa17b-121c-4c0d-a13b-e8aad9212d95',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'date': 'Fri, 19 Jun 2020 19:54:21 GMT',
#      'content-type': 'application/x-amz-json-1.1',
#      'content-length': '15324',
#      'connection': 'keep-alive',
#      'x-amzn-requestid': 'db0aa17b-121c-4c0d-a13b-e8aad9212d95'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:21.946172'},
#   {'QueryExecutionId': '0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#    'ResponseMetadata': {'RequestId': 'ac92eda0-065d-450e-9da6-850dff9e42f8',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:21 GMT',
#      'x-amzn-requestid': 'ac92eda0-065d-450e-9da6-850dff9e42f8',
#      'content-length': '59',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:22.370675'},
#   {'QueryExecution': {'QueryExecutionId': '0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#     'Query': "CREATE EXTERNAL TABLE IF NOT EXISTS `crawler_poc`.`part_data_merged` (\n`widget` STRING,\n`price` DOUBLE,\n`manufacturer` STRING,\n`in_stock` BOOLEAN\n)\nSTORED AS PARQUET\nLOCATION 's3://spg-mason-demo/part_data_merged/'",
#     'StatementType': 'DDL',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/0d2fb38b-5b7a-40b9-816b-52eccbe41039.txt'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'RUNNING',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 22, 304000, tzinfo=tzlocal())},
#     'Statistics': {'TotalExecutionTimeInMillis': 264,
#      'QueryQueueTimeInMillis': 55},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': 'ebba07f6-d29f-418d-9aa1-dc0631bb61cb',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:21 GMT',
#      'x-amzn-requestid': 'ebba07f6-d29f-418d-9aa1-dc0631bb61cb',
#      'content-length': '1316',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:22.606214'},
#   {'Error': {'Message': 'Query has not yet finished. Current state: RUNNING',
#     'Code': 'InvalidRequestException'},
#    'ResponseMetadata': {'RequestId': '78aa1f97-8f0d-42b8-8b62-dfaea163bd3f',
#     'HTTPStatusCode': 400,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:22 GMT',
#      'x-amzn-requestid': '78aa1f97-8f0d-42b8-8b62-dfaea163bd3f',
#      'content-length': '193',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:22.812393'},
#   {'QueryExecution': {'QueryExecutionId': '0d2fb38b-5b7a-40b9-816b-52eccbe41039',
#     'Query': "CREATE EXTERNAL TABLE IF NOT EXISTS `crawler_poc`.`part_data_merged` (\n`widget` STRING,\n`price` DOUBLE,\n`manufacturer` STRING,\n`in_stock` BOOLEAN\n)\nSTORED AS PARQUET\nLOCATION 's3://spg-mason-demo/part_data_merged/'",
#     'StatementType': 'DDL',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/0d2fb38b-5b7a-40b9-816b-52eccbe41039.txt'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'SUCCEEDED',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 22, 304000, tzinfo=tzlocal()),
#      'CompletionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 22, 754000, tzinfo=tzlocal())},
#     'Statistics': {'EngineExecutionTimeInMillis': 365,
#      'DataScannedInBytes': 0,
#      'TotalExecutionTimeInMillis': 450,
#      'QueryQueueTimeInMillis': 55,
#      'ServiceProcessingTimeInMillis': 30},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': '2f273530-8cf6-4b8c-8ee2-9ad989278796',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:32 GMT',
#      'x-amzn-requestid': '2f273530-8cf6-4b8c-8ee2-9ad989278796',
#      'content-length': '1605',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:33.060688'},
#   {'ResultSet': {'Rows': [], 'ResultSetMetadata': {'ColumnInfo': []}},
#    'ResponseMetadata': {'RequestId': 'a1c398dd-090d-4921-8a2e-fcd275ff7ed1',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:32 GMT',
#      'x-amzn-requestid': 'a1c398dd-090d-4921-8a2e-fcd275ff7ed1',
#      'content-length': '108',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:33.350742'},
#   {'TableList': [{'Name': 'complex_json_2_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 16, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field6:string>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json_2.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '272',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '272',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '272',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '272',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'complex_json_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'data',
#         'Type': 'array<struct<field1:string,field2:string,field3:string,field4:string,field5:struct<some_other_stuff:string>>>'}],
#       'Location': 's3://spg-mason-demo/part_data_json/complex_json.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'data'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '302',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '302',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '302',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '302',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'json_simple_json',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 17, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'field', 'Type': 'string'},
#        {'Name': 'field2', 'Type': 'string'},
#        {'Name': 'field3', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/part_data_json/json_simple.json',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.openx.data.jsonserde.JsonSerDe',
#        'Parameters': {'paths': 'field,field2,field3'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '58',
#        'classification': 'json',
#        'compressionType': 'none',
#        'recordCount': '1',
#        'sizeKey': '58',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '58',
#       'classification': 'json',
#       'compressionType': 'none',
#       'recordCount': '1',
#       'sizeKey': '58',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/merged/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '82',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '3',
#        'recordCount': '6',
#        'sizeKey': '2115',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '82',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '3',
#       'recordCount': '6',
#       'sizeKey': '2115',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'merged_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 9, 8, 39, 57, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1591706397'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '189',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '8',
#        'recordCount': '6',
#        'sizeKey': '5309',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '189',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '8',
#       'recordCount': '6',
#       'sizeKey': '5309',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_csv',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'col0', 'Type': 'string'},
#        {'Name': 'col1', 'Type': 'double'},
#        {'Name': 'col2', 'Type': 'string'},
#        {'Name': 'col3', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_csv/',
#       'InputFormat': 'org.apache.hadoop.mapred.TextInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe',
#        'Parameters': {'field.delim': ','}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'areColumnsQuoted': 'false',
#        'averageRecordSize': '18',
#        'classification': 'csv',
#        'columnsOrdered': 'true',
#        'compressionType': 'none',
#        'delimiter': ',',
#        'objectCount': '4',
#        'recordCount': '6',
#        'sizeKey': '117',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [{'Name': 'partition_0', 'Type': 'string'}],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'areColumnsQuoted': 'false',
#       'averageRecordSize': '18',
#       'classification': 'csv',
#       'columnsOrdered': 'true',
#       'compressionType': 'none',
#       'delimiter': ',',
#       'objectCount': '4',
#       'recordCount': '6',
#       'sizeKey': '117',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'part_data_merged',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 19, 15, 44, 47, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'widget', 'Type': 'string'},
#        {'Name': 'price', 'Type': 'double'},
#        {'Name': 'manufacturer', 'Type': 'string'},
#        {'Name': 'in_stock', 'Type': 'boolean'}],
#       'Location': 's3://spg-mason-demo/part_data_merged',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592595887'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'problem',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'owner',
#      'CreateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(2020, 4, 20, 9, 22, 15, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'index', 'Type': 'bigint'},
#        {'Name': 'transactiontime', 'Type': 'string'},
#        {'Name': 'user_master_id', 'Type': 'bigint'},
#        {'Name': 'user_name', 'Type': 'string'},
#        {'Name': 'first_name', 'Type': 'string'},
#        {'Name': 'last_name', 'Type': 'string'},
#        {'Name': 'full_name', 'Type': 'string'},
#        {'Name': 'facility_id', 'Type': 'bigint'},
#        {'Name': 'title_id', 'Type': 'bigint'},
#        {'Name': 'department_id', 'Type': 'bigint'},
#        {'Name': 'active', 'Type': 'string'},
#        {'Name': 'associate_number', 'Type': 'double'},
#        {'Name': 'entered_by_id', 'Type': 'bigint'},
#        {'Name': 'date_entered', 'Type': 'timestamp'},
#        {'Name': 'user_id', 'Type': 'bigint'},
#        {'Name': 'date_write', 'Type': 'timestamp'},
#        {'Name': 'date_hire', 'Type': 'timestamp'},
#        {'Name': 'birth_month', 'Type': 'double'},
#        {'Name': 'birth_day', 'Type': 'double'},
#        {'Name': 'date_terminated', 'Type': 'timestamp'},
#        {'Name': 'plant_id', 'Type': 'double'},
#        {'Name': 'itar_approved', 'Type': 'double'},
#        {'Name': 'issharedaccount', 'Type': 'double'},
#        {'Name': 'rowguid', 'Type': 'string'},
#        {'Name': 'dateofbirth', 'Type': 'timestamp'},
#        {'Name': 'exporttoexternal', 'Type': 'double'},
#        {'Name': 'dateupdatetocsod', 'Type': 'timestamp'},
#        {'Name': 'productivitycenterid', 'Type': 'double'},
#        {'Name': 'ar_h_change_seq', 'Type': 'string'},
#        {'Name': 'ar_h_stream_position', 'Type': 'string'},
#        {'Name': 'op', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/problem/',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#        'CrawlerSchemaSerializerVersion': '1.0',
#        'UPDATED_BY_CRAWLER': 'crawler_poc',
#        'averageRecordSize': '277',
#        'classification': 'parquet',
#        'compressionType': 'none',
#        'objectCount': '2',
#        'recordCount': '23423',
#        'sizeKey': '1310155',
#        'typeOfData': 'file'},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'CrawlerSchemaDeserializerVersion': '1.0',
#       'CrawlerSchemaSerializerVersion': '1.0',
#       'UPDATED_BY_CRAWLER': 'crawler_poc',
#       'averageRecordSize': '277',
#       'classification': 'parquet',
#       'compressionType': 'none',
#       'objectCount': '2',
#       'recordCount': '23423',
#       'sizeKey': '1310155',
#       'typeOfData': 'file'},
#      'CreatedBy': 'arn:aws:sts::062325279035:assumed-role/AWSGlueServiceRole-anduin-data-glue/AWS-Crawler',
#      'IsRegisteredWithLakeFormation': False},
#     {'Name': 'test_table',
#      'DatabaseName': 'crawler_poc',
#      'Owner': 'hadoop',
#      'CreateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'UpdateTime': datetime.datetime(2020, 6, 17, 15, 19, 6, tzinfo=tzlocal()),
#      'LastAccessTime': datetime.datetime(1969, 12, 31, 19, 0, tzinfo=tzlocal()),
#      'Retention': 0,
#      'StorageDescriptor': {'Columns': [{'Name': 'crane', 'Type': 'string'},
#        {'Name': '5000.0', 'Type': 'string'},
#        {'Name': 'case', 'Type': 'string'},
#        {'Name': 'false', 'Type': 'string'}],
#       'Location': 's3://spg-mason-demo/merged_csv',
#       'InputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat',
#       'OutputFormat': 'org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat',
#       'Compressed': False,
#       'NumberOfBuckets': -1,
#       'SerdeInfo': {'SerializationLibrary': 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe',
#        'Parameters': {'serialization.format': '1'}},
#       'BucketColumns': [],
#       'SortColumns': [],
#       'Parameters': {},
#       'SkewedInfo': {'SkewedColumnNames': [],
#        'SkewedColumnValues': [],
#        'SkewedColumnValueLocationMaps': {}},
#       'StoredAsSubDirectories': False},
#      'PartitionKeys': [],
#      'TableType': 'EXTERNAL_TABLE',
#      'Parameters': {'EXTERNAL': 'TRUE', 'transient_lastDdlTime': '1592421546'},
#      'CreatedBy': 'arn:aws:iam::062325279035:user/kops',
#      'IsRegisteredWithLakeFormation': False}],
#    'ResponseMetadata': {'RequestId': '4456b5e7-13b3-4f5e-acfd-606e29209d8d',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'content-type': 'application/x-amz-json-1.1',
#      'content-length': '15324',
#      'connection': 'keep-alive',
#      'x-amzn-requestid': '4456b5e7-13b3-4f5e-acfd-606e29209d8d'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:33.692323'},
#   {'QueryExecutionId': 'b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#    'ResponseMetadata': {'RequestId': '02f32c7a-c258-4cd6-b88b-48b867d5bf33',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'x-amzn-requestid': '02f32c7a-c258-4cd6-b88b-48b867d5bf33',
#      'content-length': '59',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:34.023024'},
#   {'QueryExecution': {'QueryExecutionId': 'b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#     'Query': 'SELECT * from part_data_merged',
#     'StatementType': 'DML',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/b5b045ad-029b-4cc3-920c-10d48a25fe0e.csv'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'QUEUED',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 33, 952000, tzinfo=tzlocal())},
#     'Statistics': {'TotalExecutionTimeInMillis': 222,
#      'QueryQueueTimeInMillis': 222},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': 'c52ccc82-0bf3-4f4f-958e-4dea84511c6e',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'x-amzn-requestid': 'c52ccc82-0bf3-4f4f-958e-4dea84511c6e',
#      'content-length': '934',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:34.210845'},
#   {'Error': {'Message': 'Query has not yet finished. Current state: RUNNING',
#     'Code': 'InvalidRequestException'},
#    'ResponseMetadata': {'RequestId': '8c685ec7-9917-4f5f-9d3f-d4eefa5a704b',
#     'HTTPStatusCode': 400,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:33 GMT',
#      'x-amzn-requestid': '8c685ec7-9917-4f5f-9d3f-d4eefa5a704b',
#      'content-length': '193',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:34.427014'},
#   {'QueryExecution': {'QueryExecutionId': 'b5b045ad-029b-4cc3-920c-10d48a25fe0e',
#     'Query': 'SELECT * from part_data_merged',
#     'StatementType': 'DML',
#     'ResultConfiguration': {'OutputLocation': 's3://mason-athena-results/b5b045ad-029b-4cc3-920c-10d48a25fe0e.csv'},
#     'QueryExecutionContext': {'Database': 'crawler_poc'},
#     'Status': {'State': 'SUCCEEDED',
#      'SubmissionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 33, 952000, tzinfo=tzlocal()),
#      'CompletionDateTime': datetime.datetime(2020, 6, 19, 15, 54, 34, 704000, tzinfo=tzlocal())},
#     'Statistics': {'EngineExecutionTimeInMillis': 597,
#      'DataScannedInBytes': 506,
#      'TotalExecutionTimeInMillis': 752,
#      'QueryQueueTimeInMillis': 135,
#      'QueryPlanningTimeInMillis': 254,
#      'ServiceProcessingTimeInMillis': 20},
#     'WorkGroup': 'mason'},
#    'ResponseMetadata': {'RequestId': 'cb980a0b-48c3-426e-95c3-fa20aa57158f',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:43 GMT',
#      'x-amzn-requestid': 'cb980a0b-48c3-426e-95c3-fa20aa57158f',
#      'content-length': '1262',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:44.614777'},
#   {'UpdateCount': 0,
#    'ResultSet': {'Rows': [{'Data': [{'VarCharValue': 'widget'},
#        {'VarCharValue': 'price'},
#        {'VarCharValue': 'manufacturer'},
#        {'VarCharValue': 'in_stock'}]},
#      {'Data': [{'VarCharValue': 'tractor'},
#        {'VarCharValue': '10000.0'},
#        {'VarCharValue': 'John Deer'},
#        {'VarCharValue': 'true'}]},
#      {'Data': [{'VarCharValue': 'forklift'},
#        {'VarCharValue': '4000.0'},
#        {'VarCharValue': 'Bobcat'},
#        {'VarCharValue': 'true'}]},
#      {'Data': [{'VarCharValue': 'crane'},
#        {'VarCharValue': '5000.0'},
#        {'VarCharValue': 'Case'},
#        {'VarCharValue': 'false'}]},
#      {'Data': [{'VarCharValue': 'wrench'}, {'VarCharValue': '20.0'}, {}, {}]},
#      {'Data': [{'VarCharValue': 'casing'}, {'VarCharValue': '30.0'}, {}, {}]},
#      {'Data': [{'VarCharValue': 'bolt'}, {'VarCharValue': '25.0'}, {}, {}]}],
#     'ResultSetMetadata': {'ColumnInfo': [{'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'widget',
#        'Label': 'widget',
#        'Type': 'varchar',
#        'Precision': 2147483647,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': True},
#       {'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'price',
#        'Label': 'price',
#        'Type': 'double',
#        'Precision': 17,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': False},
#       {'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'manufacturer',
#        'Label': 'manufacturer',
#        'Type': 'varchar',
#        'Precision': 2147483647,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': True},
#       {'CatalogName': 'hive',
#        'SchemaName': '',
#        'TableName': '',
#        'Name': 'in_stock',
#        'Label': 'in_stock',
#        'Type': 'boolean',
#        'Precision': 0,
#        'Scale': 0,
#        'Nullable': 'UNKNOWN',
#        'CaseSensitive': False}]}},
#    'ResponseMetadata': {'RequestId': '9262539c-bacb-4a90-a79f-0d72e4744a98',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#      'date': 'Fri, 19 Jun 2020 19:54:44 GMT',
#      'x-amzn-requestid': '9262539c-bacb-4a90-a79f-0d72e4744a98',
#      'content-length': '2504',
#      'connection': 'keep-alive'},
#     'RetryAttempts': 0},
#    'timestamp': '2020-06-19 15:54:44.931223'}]}
